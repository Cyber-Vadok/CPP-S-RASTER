# %%
import pandas as pd
from sklearn.metrics import silhouette_score, silhouette_samples
import numpy as np

def silhouette_score_wtime(file):

    df = pd.read_csv(file)

    # Assicurati che le colonne siano nel formato corretto
    df['time'] = df['time'].astype(int)  # Assicurati che 'time' sia numerico

    # Usa solo le colonne delle coordinate e del cluster ID
    X = df[["x", "y"]].values  # Array con coordinate x e y
    labels = df["cluster_id"].values  # Array con l'ID del cluster
    time_values = df["time"].values  # Array con i valori di time

    # Crea una lista per memorizzare i silhouette score medi per ciascun time
    silhouette_avg_per_time = []

    # Crea una lista per visualizzare il silhouette score per ogni punto
    silhouette_values = silhouette_samples(X, labels)

    # Calcola il silhouette score per ogni valore di time
    unique_times = np.unique(time_values)  # Trova i tempi unici
    for time in unique_times:
        # Seleziona i dati corrispondenti a questo time
        # https://www.educative.io/answers/what-is-boolean-masking-on-numpy-arrays-in-python
        time_mask = time_values == time
        X_time = X[time_mask]
        labels_time = labels[time_mask]

        # Calcola il silhouette score per questo time
        silhouette_avg = silhouette_score(X_time, labels_time)
        silhouette_avg_per_time.append(silhouette_avg)
        print(f"Silhouette Score per il time {time}: {silhouette_avg}")

    # Calcola il silhouette score medio per l'intero dataset
    silhouette_avg_overall = np.mean(silhouette_avg_per_time)
    print(f"Silhouette Score medio complessivo: {silhouette_avg_overall}")
    
    return silhouette_avg_overall

# %%
silhouette_score_wtime("/home/robivad/Git/CPP-S-RASTER/data_output/n100_p500/mu1_tau1.csv")
# Out:
# Silhouette Score per il time 0: 0.9999786325255239
# Silhouette Score per il time 1: 0.9999524315890196
# Silhouette Score per il time 2: 0.9999753202322729
# Silhouette Score per il time 3: 0.9999769382290872
# Silhouette Score per il time 4: 0.9999601173856647
# Silhouette Score per il time 5: 0.9999700424172562
# Silhouette Score per il time 6: 0.9999747336333821
# Silhouette Score per il time 7: 0.999943634593724
# Silhouette Score per il time 8: 0.9999692273507685
# Silhouette Score per il time 9: 0.9999664763503516
# Silhouette Score medio complessivo: 0.999966755430705
# np.float64(0.999966755430705)

# %%
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Funzione principale per generare la matrice e la heatmap
def process_files_and_plot_heatmap(input_path, mu_range, tau_range):
    """
    Processa i file CSV e genera una heatmap con silhouette scores.
    Parametri:
        input_path (str): Cartella contenente i file CSV.
        mu_range (range): Range dei valori di mu.
        tau_range (range): Range dei valori di tau.
        n_clusters (int): Numero di cluster per silhouette score.
    """
    # Matrice per salvare i risultati
    silhouette_matrix = np.zeros((len(tau_range), len(mu_range)))

    # Itera sui valori di mu e tau
    for i, tau in enumerate(tau_range):
        for j, mu in enumerate(mu_range):
            # Costruisci il nome del file
            file_name = f"mu{mu}_tau{tau}.csv"
            file_path = os.path.join(input_path, file_name)
            
            if os.path.isfile(file_path):
                # Calcola il silhouette score
                score = silhouette_score_wtime(file_path)
                if score is not None:
                    silhouette_matrix[i, j] = score
                else:
                    silhouette_matrix[i, j] = np.nan  # Se errore, assegna NaN
            else:
                print(f"File non trovato: {file_path}")
                silhouette_matrix[i, j] = np.nan

    # Visualizza la matrice come heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(silhouette_matrix, annot=True, fmt=".3f", cmap="viridis", 
                xticklabels=mu_range, yticklabels=tau_range)
    plt.title("Silhouette Score Heatmap")
    plt.xlabel("Mu")
    plt.ylabel("Tau")
    plt.show()

# Parametri
input_path = "/home/robivad/Git/CPP-S-RASTER/data_output/n1000_p5000"  # Sostituisci con il percorso corretto
mu_range = range(1, 11)  # Mu da 1 a 10
tau_range = range(1, 11)  # Tau da 1 a 10

# Esegui lo script
process_files_and_plot_heatmap(input_path, mu_range, tau_range)
# Out:
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998488564101582
# Silhouette Score per il time 1: 0.9998658130652616
# Silhouette Score per il time 2: 0.9998668595319383
# Silhouette Score per il time 3: 0.9998482430630623
# Silhouette Score per il time 4: 0.9998087250880958
# Silhouette Score per il time 5: 0.9998513877920088
# Silhouette Score per il time 6: 0.9998801714941011
# Silhouette Score per il time 7: 0.9998913562519653
# Silhouette Score per il time 8: 0.9998589453094415
# Silhouette Score per il time 9: 0.9998164720295428
# Silhouette Score medio complessivo: 0.9998536830035576
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998527128051696
# Silhouette Score per il time 1: 0.9998684074475774
# Silhouette Score per il time 2: 0.999869867646505
# Silhouette Score per il time 3: 0.9998504418069698
# Silhouette Score per il time 4: 0.9998177463983862
# Silhouette Score per il time 5: 0.9998556987713842
# Silhouette Score per il time 6: 0.9998845482699042
# Silhouette Score per il time 7: 0.9998949192571059
# Silhouette Score per il time 8: 0.9998602995925089
# Silhouette Score per il time 9: 0.9998224463055027
# Silhouette Score medio complessivo: 0.9998577088301014
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998554718358286
# Silhouette Score per il time 1: 0.9998704891161446
# Silhouette Score per il time 2: 0.9998729991262333
# Silhouette Score per il time 3: 0.9998527046316655
# Silhouette Score per il time 4: 0.9998221862002394
# Silhouette Score per il time 5: 0.9998582492492138
# Silhouette Score per il time 6: 0.9998867240014304
# Silhouette Score per il time 7: 0.9998974702071373
# Silhouette Score per il time 8: 0.999863295899158
# Silhouette Score per il time 9: 0.999824340458209
# Silhouette Score medio complessivo: 0.9998603930725262
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.9998577994900849
# Silhouette Score per il time 1: 0.999872629885565
# Silhouette Score per il time 2: 0.9998751408824245
# Silhouette Score per il time 3: 0.999856422637366
# Silhouette Score per il time 4: 0.9998250647762604
# Silhouette Score per il time 5: 0.9998606865628485
# Silhouette Score per il time 6: 0.9998888225864218
# Silhouette Score per il time 7: 0.9998989931222687
# Silhouette Score per il time 8: 0.9998650309086454
# Silhouette Score per il time 9: 0.9998261108446201
# Silhouette Score medio complessivo: 0.9998626701696505
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.99986011106144
# Silhouette Score per il time 1: 0.9998738295769127
# Silhouette Score per il time 2: 0.9998778160022481
# Silhouette Score per il time 3: 0.9998588232569148
# Silhouette Score per il time 4: 0.9998293810056995
# Silhouette Score per il time 5: 0.9998629967670276
# Silhouette Score per il time 6: 0.999890612194612
# Silhouette Score per il time 7: 0.9999009694135748
# Silhouette Score per il time 8: 0.9998669125695301
# Silhouette Score per il time 9: 0.9998297851501395
# Silhouette Score medio complessivo: 0.9998651236998098
# Silhouette Score per il time 0: 0.9998616400212134
# Silhouette Score per il time 1: 0.9998758622130873
# Silhouette Score per il time 2: 0.9998795206480402
# Silhouette Score per il time 3: 0.9998608930120965
# Silhouette Score per il time 4: 0.9998299676258678
# Silhouette Score per il time 5: 0.9998656078851704
# Silhouette Score per il time 6: 0.999891841048664
# Silhouette Score per il time 7: 0.99990187782531
# Silhouette Score per il time 8: 0.9998685344813223
# Silhouette Score per il time 9: 0.9998314623298212
# Silhouette Score medio complessivo: 0.9998667207090592
# Silhouette Score per il time 0: 0.9998616400212134
# Silhouette Score per il time 1: 0.9998758622130873
# Silhouette Score per il time 2: 0.9998795206480402
# Silhouette Score per il time 3: 0.9998608930120965
# Silhouette Score per il time 4: 0.9998299676258678
# Silhouette Score per il time 5: 0.9998656078851704
# Silhouette Score per il time 6: 0.999891841048664
# Silhouette Score per il time 7: 0.99990187782531
# Silhouette Score per il time 8: 0.9998685344813223
# Silhouette Score per il time 9: 0.9998314623298212
# Silhouette Score medio complessivo: 0.9998667207090592
# Silhouette Score per il time 0: 0.9998616400212134
# Silhouette Score per il time 1: 0.9998758622130873
# Silhouette Score per il time 2: 0.9998795206480402
# Silhouette Score per il time 3: 0.9998608930120965
# Silhouette Score per il time 4: 0.9998299676258678
# Silhouette Score per il time 5: 0.9998656078851704
# Silhouette Score per il time 6: 0.999891841048664
# Silhouette Score per il time 7: 0.99990187782531
# Silhouette Score per il time 8: 0.9998685344813223
# Silhouette Score per il time 9: 0.9998314623298212
# Silhouette Score medio complessivo: 0.9998667207090592
# Silhouette Score per il time 0: 0.9998616400212134
# Silhouette Score per il time 1: 0.9998758622130873
# Silhouette Score per il time 2: 0.9998795206480402
# Silhouette Score per il time 3: 0.9998608930120965
# Silhouette Score per il time 4: 0.9998299676258678
# Silhouette Score per il time 5: 0.9998656078851704
# Silhouette Score per il time 6: 0.999891841048664
# Silhouette Score per il time 7: 0.99990187782531
# Silhouette Score per il time 8: 0.9998685344813223
# Silhouette Score per il time 9: 0.9998314623298212
# Silhouette Score medio complessivo: 0.9998667207090592
# Silhouette Score per il time 0: 0.9998616400212134
# Silhouette Score per il time 1: 0.9998758622130873
# Silhouette Score per il time 2: 0.9998795206480402
# Silhouette Score per il time 3: 0.9998608930120965
# Silhouette Score per il time 4: 0.9998299676258678
# Silhouette Score per il time 5: 0.9998656078851704
# Silhouette Score per il time 6: 0.999891841048664
# Silhouette Score per il time 7: 0.99990187782531
# Silhouette Score per il time 8: 0.9998685344813223
# Silhouette Score per il time 9: 0.9998314623298212
# Silhouette Score medio complessivo: 0.9998667207090592
# Silhouette Score per il time 0: 0.9998616400212134
# Silhouette Score per il time 1: 0.9998758622130873
# Silhouette Score per il time 2: 0.9998795206480402
# Silhouette Score per il time 3: 0.9998608930120965
# Silhouette Score per il time 4: 0.9998299676258678
# Silhouette Score per il time 5: 0.9998656078851704
# Silhouette Score per il time 6: 0.999891841048664
# Silhouette Score per il time 7: 0.99990187782531
# Silhouette Score per il time 8: 0.9998685344813223
# Silhouette Score per il time 9: 0.9998314623298212
# Silhouette Score medio complessivo: 0.9998667207090592
# Silhouette Score per il time 0: 0.9998616400212134
# Silhouette Score per il time 1: 0.9998758622130873
# Silhouette Score per il time 2: 0.9998795206480402
# Silhouette Score per il time 3: 0.9998608930120965
# Silhouette Score per il time 4: 0.9998299676258678
# Silhouette Score per il time 5: 0.9998656078851704
# Silhouette Score per il time 6: 0.999891841048664
# Silhouette Score per il time 7: 0.99990187782531
# Silhouette Score per il time 8: 0.9998685344813223
# Silhouette Score per il time 9: 0.9998314623298212
# Silhouette Score medio complessivo: 0.9998667207090592
# Silhouette Score per il time 0: 0.9998616400212134
# Silhouette Score per il time 1: 0.9998758622130873
# Silhouette Score per il time 2: 0.9998795206480402
# Silhouette Score per il time 3: 0.9998608930120965
# Silhouette Score per il time 4: 0.9998299676258678
# Silhouette Score per il time 5: 0.9998656078851704
# Silhouette Score per il time 6: 0.999891841048664
# Silhouette Score per il time 7: 0.99990187782531
# Silhouette Score per il time 8: 0.9998685344813223
# Silhouette Score per il time 9: 0.9998314623298212
# Silhouette Score medio complessivo: 0.9998667207090592
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 52
#      49 tau_range = range(1, 11)  # Tau da 1 a 10
#      51 # Esegui lo script
# ---> 52 process_files_and_plot_heatmap(input_path, mu_range, tau_range)
#
# Cell In[13], line 28, in process_files_and_plot_heatmap(input_path, mu_range, tau_range)
#      24 file_path = os.path.join(input_path, file_name)
#      26 if os.path.isfile(file_path):
#      27     # Calcola il silhouette score
# ---> 28     score = silhouette_score_wtime(file_path)
#      29     if score is not None:
#      30         silhouette_matrix[i, j] = score
#
# Cell In[8], line 21, in silhouette_score_wtime(file)
#      18 silhouette_avg_per_time = []
#      20 # Crea una lista per visualizzare il silhouette score per ogni punto
# ---> 21 silhouette_values = silhouette_samples(X, labels)
#      23 # Calcola il silhouette score per ogni valore di time
#      24 unique_times = np.unique(time_values)  # Trova i tempi unici
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/cluster/_unsupervised.py:305, in silhouette_samples(X, labels, metric, **kwds)
#     301 kwds["metric"] = metric
#     302 reduce_func = functools.partial(
#     303     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     304 )
# --> 305 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     306 intra_clust_dists, inter_clust_dists = results
#     307 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:2172, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2170 else:
#    2171     X_chunk = X[sl]
# -> 2172 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2173 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2174     metric, None
#    2175 ) is euclidean_distances:
#    2176     # zeroing diagonal, taking care of aliases of "euclidean",
#    2177     # i.e. "l2"
#    2178     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:2375, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2372         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2373     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2375 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1893, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1890 X, Y, dtype = _return_float_dtype(X, Y)
#    1892 if effective_n_jobs(n_jobs) == 1:
# -> 1893     return func(X, Y, **kwds)
#    1895 # enforce a threading backend to prevent data communication overhead
#    1896 fd = delayed(_dist_wrapper)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:372, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     366     if Y_norm_squared.shape != (1, Y.shape[0]):
#     367         raise ValueError(
#     368             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     369             f"Y_norm_squared of shape {original_shape}."
#     370         )
# --> 372 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:410, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     408     distances += XX
#     409     distances += YY
# --> 410 np.maximum(distances, 0, out=distances)
#     412 # Ensure that distances between vectors and themselves are set to 0.0.
#     413 # This may not be the case due to floating point rounding errors.
#     414 if X is Y:
#
# KeyboardInterrupt:
